# %% [markdown]
# **Example of PennTreeBank Language Modeling**
#
# make sure that you have two directories
#
# *   drive/My Drive/public/data/ptb
# *   drive/My Drive/public/results
#
# make sure that you have three dataset files in 'drive/My Drive/public/data/ptb/' directory
#
# *   ptb.train.txt
# *   ptb.train.txt.pkl
# *   ptb.valid.txt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# import pytorch

# %%
### Import the libraries

import os
import time
import math
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable

import six; from six.moves import cPickle as pkl
import numpy as np

print("Importing libraries done!")
# Out:
# Importing libraries done!

# %% [markdown]
# define special tokens and util functinos
#
#
# *   ids2words : transform the tokenized sentence to real language sentence
# *   timeSince : compute the hours, minutes and seconds

# %%
BOS_token = 0 # Beginning Of Sentence token
EOS_token = 1 # End Of Sentence token
UNK_token = 2 # UNKnown token

### Define the util functions
def ids2words(dict_map, raw_data, sep=' ', eos_id=0, unk_sym='<unk>'):
    str_text = ''
    raw_data = raw_data.squeeze().tolist()

    # Make the dict to inverse for translate unique number to word
    dict_map_inv = dict()
    for kk, vv in dict_map.items():
        dict_map_inv[vv] = kk
 
    for vv in raw_data:
        if vv == eos_id:
            break
        if vv in dict_map_inv:
            str_text = str_text + sep + dict_map_inv[vv]
        else:
            str_text = str_text + sep + unk_sym
    return str_text.strip()

def timeSince(since):
  now = time.time()
  s = now - since

  h = math.floor(s / 3600)
  m = math.floor((s-3600*h) / 60)
  s = s - h*3600 - m*60

  return '{}h {}m {:.3f}s'.format(h,m,s)

# %% [markdown]
# define your Language Model

# %%
### Make my Language Model
class LM(nn.Module):
    def __init__(self, dict_len, dim_enc, dim_wemb, device):
        super(LM, self).__init__()
        self.dim_enc = dim_enc
        self.wemb = dim_wemb
        self.dict_len = dict_len
        self.device = device

        self.dropout = nn.Dropout(0.2)
        self.src_emb = nn.Embedding(dict_len, dim_wemb)
        self.rnn_enc = nn.LSTMCell(dim_wemb, dim_enc)

        self.readout = nn.Linear(dim_enc, dim_wemb)
        self.dec = nn.Linear(dim_wemb, dict_len)

        self.criterion = nn.CrossEntropyLoss()
        self.softmax = nn.Softmax(dim=1)

    def forward(self, data, mask=None): 
        # data : (Timeseq, Batch)
        x_data = data[:-1] # input (the last word is not the input)
        y_data = data[1:]  # label (the first word is not the label)
        if mask is not None:
            x_mask = mask[1:]
            y_mask = mask[1:]

        Tx, Bn = x_data.size()
       
        x_emb = self.src_emb(torch.reshape(x_data, (Bn*Tx,1)))
        x_emb = x_emb.view(Tx,Bn,-1)
        x_emb = self.dropout(x_emb)
        # x_emb : (Timeseq, Batch, dim_wemb)
        
        ht = torch.zeros(Bn,self.dim_enc)
        ct = torch.zeros(Bn,self.dim_enc)
        ht = Variable(ht).to(self.device)
        ct = Variable(ct).to(self.device)
        
        gen_sentence = x_data[0].unsqueeze(1) # (Batch, 1)
        loss = 0
        for i in range(Tx):
            ht, ct = self.rnn_enc(x_emb[i,:,:],(ht, ct))
            # ht, ct : (Batch, dim_enc)
            output = self.readout(ht)
            output = self.dropout(output)
            # output : (Batch, dim_wemb)
            logit = self.dec(output)
            # logit : (Batch, dict_len)
            loss_tmp = self.criterion(logit, y_data[i])
            
            probs = self.softmax(logit)
            topv, yt = probs.topk(1) # Choose top 1 prob. word
           
            gen_sentence = torch.cat((gen_sentence, yt), dim=1)
            if mask is not None:
                loss += torch.sum(loss_tmp*y_mask[i])/Bn
            else:
                loss += torch.sum(loss_tmp)/Bn
        
        return loss, gen_sentence

# %%
def train(model, device, train_loader, optimizer, epoch, log_interval):
    model.train()
    
    loss_total = 0
    den = 0
    for batch_idx, (data, mask) in enumerate(train_loader):
        data, mask = torch.transpose(data,1,0).to(device), torch.transpose(mask,1,0).to(device)
        optimizer.zero_grad()
        loss, gen_sentence = model(data, mask)
        loss.backward()
        optimizer.step()
 
    print('Train Epoch: {} \tLoss: {:.6f}'.format(
                epoch, loss.item()))
    real_sen = ids2words(src_dict, data[:,0], eos_id=EOS_token)
    gen_sen = ids2words(src_dict, gen_sentence[0], eos_id=EOS_token)
    print("train real sentence: {}".format(real_sen))
    print("train gen. sentence: {}".format(gen_sen))
    print("========================================")        
    return loss.item(), gen_sentence
            
def test(model, device, test_loader):
    model.eval()
    test_loss = 0
    with torch.no_grad():
        for batch_idx, (data, mask) in enumerate(test_loader):
            data, mask = torch.transpose(data,1,0).to(device), torch.transpose(mask,1,0).to(device)
            data, mask = data.to(device), mask.to(device)
            loss, gen_sentence = model(data)
            test_loss += loss

    test_loss /= batch_idx

    print('\nTest: Average loss: {:.4f}\n'.format(
        test_loss))
    return test_loss

# %% [markdown]
# define your own custom dataset

# %%
### Make my custom Dataset and DatasetLoader classes
class ptb_dataset(Dataset):
    def __init__(self,train_data,data_dict,maxlen=30):
        # Load the dataset and word_dict
        self.train_data_raw = open(train_data, 'r')
        with open(data_dict, 'rb') as f:
            self.data_dict = pkl.load(f)

        # Make dict has unique index
        self.data_dict2 = dict()
        for kk, vv in self.data_dict.items():
            self.data_dict2[kk] = vv + 1
        self.data_dict2['<s>'] = BOS_token

        self.maxlen = maxlen
        
        # Pre-processing the datasets
        self.train_data, self.train_len = self.data_init(self.train_data_raw)
    
    def __getitem__(self, index):
        sentence = self.train_data[index,:self.train_len[index]]
        x_data, x_mask = self.prepare_text(sentence)
        return torch.tensor(x_data).type(torch.long),\
               torch.tensor(x_mask).type(torch.float)
 
    def __len__(self):
        return len(self.train_data)

    def dict_len(self):
        return len(self.data_dict2)
    
    def use_dict(self):
        return self.data_dict2

    def data_init(self, data):
        #Check the number of sample < maxlen
        num = 0
        while True:
            sentence = data.readline()
            if sentence == "":
                break
            if len(sentence.strip().split()) >= self.maxlen:
                continue
            else:
                num += 1    
        # Make the preprocessed dataset
        dataset = np.zeros((num, self.maxlen))
        data_len = np.zeros(num, dtype=np.int)
        idx = 0
        data.seek(0)
        while True:
            sentence = data.readline()
            if sentence == "": # End of the dataset
                break
            # Make sentence to word level (splitted by space)
            sentence = sentence.strip().split() 
            if len(sentence) >= self.maxlen:
                continue
            else:
                sentence = [self.data_dict2.get(key, UNK_token)\
                                         for key in sentence]
                dataset[idx,:len(sentence)] = sentence
                data_len[idx] = len(sentence)
                idx += 1
        return dataset, data_len
    
    def prepare_text(self, sentence):
        maxlen = self.maxlen + 2 # +2 for BOS and EOS
        x_data = np.ones(maxlen).astype('int64')
        x_mask = np.zeros(maxlen).astype('float32')
        x_data[1:len(sentence)+1] = sentence
        x_data[0] = BOS_token
        x_mask[:len(sentence)+2] = 1. # EOS token

        return x_data, x_mask    

def ptb_loader(train_data, batch_size, maxlen):
    data_dict = 'drive/My Drive/public/data/ptb/ptb.train.txt.pkl'

    data = ptb_dataset(train_data, data_dict, maxlen=maxlen)
    src_dict = data.use_dict()
    
    data_loader = DataLoader(data, batch_size=batch_size, shuffle=False)
    
    return data_loader, data.dict_len(), src_dict

# %%
### Test my dataset, datasetloader classes
batch_size = 1
maxlen = 30

train_data = 'drive/My Drive/public/data/ptb/ptb.train.txt'
train_loader, dict_len, src_dict = ptb_loader(train_data, batch_size, maxlen)

for i, (x_data, x_mask) in enumerate(train_loader):
    real_sen = ids2words(src_dict, x_data, eos_id=EOS_token)
    print("----------------------------------------------------------")
    print("real sentence: ")
    print(real_sen)
    print("x_data.shape: ", x_data.shape)
    print("x_data:")
    print(x_data)
    print("x_mask:")
    print(x_mask)
    print("----------------------------------------------------------")

    if i >= 5:
        break

# %%
### Hyperparameters
batch_size = 64
test_batch_size=1
maxlen = 30
dim_enc = 400
dim_emb = 300
lr = 0.0001
optimizer = 'Adam'
max_epoch = 100

# %%
### Training
train_data = 'drive/My Drive/public/data/ptb/ptb.train.txt'
test_data = 'drive/My Drive/public/data/ptb/ptb.valid.txt'

# Check the device
cuda = torch.cuda.is_available()
device = torch.device("cuda" if cuda else "cpu")

# build my dataset loader
train_loader, dict_len, src_dict = ptb_loader(train_data, batch_size, maxlen)
test_loader, _, _ = ptb_loader(test_data, test_batch_size, maxlen)

# build my model
model = LM(dict_len, dim_enc, dim_emb, device)
model.to(device)

# build the optimizer
if optimizer == 'RMSprop':
    opt = optim.RMSprop(model.parameters(), lr=lr)
elif optimizer == 'Adam':
    opt = optim.Adam(model.parameters(), lr=lr)
elif optimizer == 'Adadelta':
    opt = optim.Adadelta(model.parameters(), lr=lr)
else:
    opt = optim.SGD(model.parameters(), lr=lr)

# Training..
print("Training Start!")
best_loss = 99999
for epoch in range(max_epoch):
    train(model, device, train_loader, opt, epoch, log_interval)
    test_loss = test(model, device, test_loader)

    if best_loss > test_loss:
        print("We found the best model!")
        best_loss = test_loss
        save_dir = 'drive/My Drive/public/results/ptb_trained_model_best.pth'
        if os.path.exists(save_dir):
            os.remove(save_dir)
        torch.save(model, save_dir)

print("Training is done!!")
# Out:
# Training Start!
# Train Epoch: 0 	Loss: 87.210655
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> <unk> <unk>
# ========================================
#
# Test: Average loss: 115.9713
#
# We found the best model!
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:402: UserWarning: Couldn't retrieve source code for container of type LM. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# Train Epoch: 1 	Loss: 82.682449
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> 's 's the a be N million
# ========================================
#
# Test: Average loss: 111.1287
#
# We found the best model!
# Train Epoch: 2 	Loss: 79.619064
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> of of to to N N million
# ========================================
#
# Test: Average loss: 107.7822
#
# We found the best model!
# Train Epoch: 3 	Loss: 77.510902
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> of <unk> of to $ N million
# ========================================
#
# Test: Average loss: 105.5721
#
# We found the best model!
# Train Epoch: 4 	Loss: 75.311218
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> 's <unk> the to N N million
# ========================================
#
# Test: Average loss: 103.9274
#
# We found the best model!
# Train Epoch: 5 	Loss: 74.047607
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> is <unk> was to $ N million
# ========================================
#
# Test: Average loss: 102.6058
#
# We found the best model!
# Train Epoch: 6 	Loss: 72.287987
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> was was was to $ N million from the
# ========================================
#
# Test: Average loss: 101.5239
#
# We found the best model!
# Train Epoch: 7 	Loss: 71.097137
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> <unk> is is to N N million from the
# ========================================
#
# Test: Average loss: 100.5754
#
# We found the best model!
# Train Epoch: 8 	Loss: 69.679771
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> is and to to $ N million from the
# ========================================
#
# Test: Average loss: 99.7526
#
# We found the best model!
# Train Epoch: 9 	Loss: 69.288887
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company is and is to the N million from the
# ========================================
#
# Test: Average loss: 99.0370
#
# We found the best model!
# Train Epoch: 10 	Loss: 68.344185
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> is was was to $ N million from the
# ========================================
#
# Test: Average loss: 98.4239
#
# We found the best model!
# Train Epoch: 11 	Loss: 67.331505
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> was was was to N N million from the
# ========================================
#
# Test: Average loss: 97.8745
#
# We found the best model!
# Train Epoch: 12 	Loss: 66.990349
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> <unk> deficit was to $ N million from the
# ========================================
#
# Test: Average loss: 97.3743
#
# We found the best model!
# Train Epoch: 13 	Loss: 65.464828
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company is was was to N N million from N and
# ========================================
#
# Test: Average loss: 96.9497
#
# We found the best model!
# Train Epoch: 14 	Loss: 64.945000
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> has and was to the N million from the
# ========================================
#
# Test: Average loss: 96.5963
#
# We found the best model!
# Train Epoch: 15 	Loss: 64.526718
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> is deficit was to $ N million from N
# ========================================
#
# Test: Average loss: 96.2354
#
# We found the best model!
# Train Epoch: 16 	Loss: 63.415390
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> is maker was to N N million from the
# ========================================
#
# Test: Average loss: 95.9759
#
# We found the best model!
# Train Epoch: 17 	Loss: 62.864136
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> is deficit the to the N million from the from
# ========================================
#
# Test: Average loss: 95.6385
#
# We found the best model!
# Train Epoch: 18 	Loss: 62.276100
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company currency deficit was to $ N billion from the
# ========================================
#
# Test: Average loss: 95.3680
#
# We found the best model!
# Train Epoch: 19 	Loss: 62.030117
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> is deficit was to N N million from the
# ========================================
#
# Test: Average loss: 95.1411
#
# We found the best model!
# Train Epoch: 20 	Loss: 61.345440
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company is deficit was to the N million from the from the and the company 's largest <unk> is been
# ========================================
#
# Test: Average loss: 94.9570
#
# We found the best model!
# Train Epoch: 21 	Loss: 60.837597
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> has deficit was to the N million from the from N to the company 's largest earthquake is been a
# ========================================
#
# Test: Average loss: 94.7837
#
# We found the best model!
# Train Epoch: 22 	Loss: 60.239857
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company is deficit is to be N million from the from the the the company 's largest and to been
# ========================================
#
# Test: Average loss: 94.6065
#
# We found the best model!
# Train Epoch: 23 	Loss: 59.854111
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company attorney deficit was to N N billion from the
# ========================================
#
# Test: Average loss: 94.5013
#
# We found the best model!
# Train Epoch: 24 	Loss: 59.330021
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> unit deficit of to the N million in the
# ========================================
#
# Test: Average loss: 94.3418
#
# We found the best model!
# Train Epoch: 25 	Loss: 58.155380
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> is deficit was to N N million from N from <unk> and the company 's largest growth
# ========================================
#
# Test: Average loss: 94.2394
#
# We found the best model!
# Train Epoch: 26 	Loss: 57.817005
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company is deficit was to $ N million from N from $ the the <unk> 's largest price is been
# ========================================
#
# Test: Average loss: 94.1633
#
# We found the best model!
# Train Epoch: 27 	Loss: 57.701469
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company unit deficit of to the N billion from N from from to the company 's largest level of been
# ========================================
#
# Test: Average loss: 94.0892
#
# We found the best model!
# Train Epoch: 28 	Loss: 57.098888
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company attorney deficit was to N N million from the from the for the <unk> 's largest earthquake would been
# ========================================
#
# Test: Average loss: 93.9457
#
# We found the best model!
# Train Epoch: 29 	Loss: 56.857533
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company is deficit is to N N million in the from the the the company 's largest <unk> is been
# ========================================
#
# Test: Average loss: 93.8700
#
# We found the best model!
# Train Epoch: 30 	Loss: 56.319351
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> unit deficit was to $ N million in the from
# ========================================
#
# Test: Average loss: 93.9177
#
# Train Epoch: 31 	Loss: 56.256710
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> is deficit in to N N million from N from
# ========================================
#
# Test: Average loss: 93.8691
#
# We found the best model!
# Train Epoch: 32 	Loss: 55.954941
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> is deficit was to the N billion from august from <unk> from the company 's largest level have been
# ========================================
#
# Test: Average loss: 93.7926
#
# We found the best model!
# Train Epoch: 33 	Loss: 55.427704
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> is deficit of to $ N million from N from $ the the <unk> 's largest earthquake
# ========================================
#
# Test: Average loss: 93.7917
#
# We found the best model!
# Train Epoch: 34 	Loss: 55.430367
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company has deficit was to the N billion from august from the the the <unk> 's largest earthquake is been the
# ========================================
#
# Test: Average loss: 93.7123
#
# We found the best model!
# Train Epoch: 35 	Loss: 55.155300
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> unit deficit was to N N million from august
# ========================================
#
# Test: Average loss: 93.8104
#
# Train Epoch: 36 	Loss: 54.238243
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company unit deficit was to the N billion in the
# ========================================
#
# Test: Average loss: 93.7603
#
# Train Epoch: 37 	Loss: 53.648312
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> unit deficit was to the N million in september
# ========================================
#
# Test: Average loss: 93.7527
#
# Train Epoch: 38 	Loss: 53.501118
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> has deficit was to the N million in september from the to the company 's largest sector is been
# ========================================
#
# Test: Average loss: 93.7474
#
# Train Epoch: 39 	Loss: 53.249275
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> is deficit of to the N million in august
# ========================================
#
# Test: Average loss: 93.7533
#
# Train Epoch: 40 	Loss: 52.946213
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> and deficit of to $ N billion from august from the from the company 's largest and
# ========================================
#
# Test: Average loss: 93.8215
#
# Train Epoch: 41 	Loss: 52.336666
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company has deficit was to N N million in august from the for the dollar 's slide level is been the
# ========================================
#
# Test: Average loss: 93.8375
#
# Train Epoch: 42 	Loss: 52.534016
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> has deficit of to the N million from september from
# ========================================
#
# Test: Average loss: 93.8576
#
# Train Epoch: 43 	Loss: 51.623322
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> has deficit was to the N billion in september from and about the <unk> 's largest price is been to
# ========================================
#
# Test: Average loss: 93.9064
#
# Train Epoch: 44 	Loss: 52.011185
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> is deficit of to the N million in N from <unk> and the company 's <unk> level is been
# ========================================
#
# Test: Average loss: 93.9551
#
# Train Epoch: 45 	Loss: 51.470432
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> has deficit was to N N billion in the from in the the economy 's <unk> <unk> is been
# ========================================
#
# Test: Average loss: 94.0754
#
# Train Epoch: 46 	Loss: 51.152363
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company is deficit deficit to the N million in august from the for the company 's largest price is been
# ========================================
#
# Test: Average loss: 94.1000
#
# Train Epoch: 47 	Loss: 50.922733
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> has deficit deficit N $ N million from august from the and the company 's second-largest sector is been
# ========================================
#
# Test: Average loss: 94.0944
#
# Train Epoch: 48 	Loss: 50.481571
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company attorney deficit was to $ N million from august
# ========================================
#
# Test: Average loss: 94.1502
#
# Train Epoch: 49 	Loss: 50.266937
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> is deficit of to the N billion from september from the the the company 's <unk> earthquake is been
# ========================================
#
# Test: Average loss: 94.2823
#
# Train Epoch: 50 	Loss: 50.679218
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> unit deficit swelled to the N billion from august from the that the dollar 's biggest sector is been damage
# ========================================
#
# Test: Average loss: 94.3126
#
# Train Epoch: 51 	Loss: 50.018059
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company has deficit deficit N N N billion from august from the the the company 's largest is is been
# ========================================
#
# Test: Average loss: 94.4327
#
# Train Epoch: 52 	Loss: 49.253521
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> attorney deficit of to N N billion from N from
# ========================================
#
# Test: Average loss: 94.4842
#
# Train Epoch: 53 	Loss: 49.491936
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> has deficit swelled to N N million from september from <unk> from the company 's largest level is been
# ========================================
#
# Test: Average loss: 94.5951
#
# Train Epoch: 54 	Loss: 48.885334
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> is deficit was to N N million in august N $ the the earthquake 's <unk> level is <unk>
# ========================================
#
# Test: Average loss: 94.6485
#
# Train Epoch: 55 	Loss: 49.069630
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> is deficit deficit to the N million from august from the about the company 's earthquake <unk> is been
# ========================================
#
# Test: Average loss: 94.7240
#
# Train Epoch: 56 	Loss: 48.708633
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company unit deficit was to N N million from august from while the the company 's <unk> price is been
# ========================================
#
# Test: Average loss: 94.8793
#
# Train Epoch: 57 	Loss: 47.957382
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> has deficit swelled to N N billion in august from the about the dollar 's largest sector is been
# ========================================
#
# Test: Average loss: 94.8569
#
# Train Epoch: 58 	Loss: 47.410412
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> has deficit swelled to N N million from N from $ the the company 's largest <unk> is been
# ========================================
#
# Test: Average loss: 95.0749
#
# Train Epoch: 59 	Loss: 47.808121
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> has deficit of to $ N million in august from analysts and the <unk> 's second-largest manufacturing is been
# ========================================
#
# Test: Average loss: 95.0966
#
# Train Epoch: 60 	Loss: 47.302071
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company is deficit swelled N $ N million from august prompting the that the company 's massive and is been
# ========================================
#
# Test: Average loss: 95.1196
#
# Train Epoch: 61 	Loss: 47.216736
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company and deficit was to the N million from september from offset that the <unk> 's massive includes would been
# ========================================
#
# Test: Average loss: 95.2092
#
# Train Epoch: 62 	Loss: 47.421925
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> has deficit swelled to N N million in august while level that the economy 's <unk> bureau is been
# ========================================
#
# Test: Average loss: 95.3487
#
# Train Epoch: 63 	Loss: 47.199486
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> attorney deficit was to the N million in august prompting $ about the company 's <unk> <unk> have been to
# ========================================
#
# Test: Average loss: 95.4077
#
# Train Epoch: 64 	Loss: 47.071651
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> is deficit of to the N billion in august from level that the company 's largest price is n't
# ========================================
#
# Test: Average loss: 95.5277
#
# Train Epoch: 65 	Loss: 45.935143
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> commerce deficit swelled to the N billion from september from the the the company 's largest <unk> is been
# ========================================
#
# Test: Average loss: 95.5998
#
# Train Epoch: 66 	Loss: 45.436108
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company <unk> deficit deficit to the N billion from august from the about the company 's earthquake <unk> have been
# ========================================
#
# Test: Average loss: 95.8204
#
# Train Epoch: 67 	Loss: 46.354580
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company attorney deficit was to the N million from N from $ from the company 's largest level is n't
# ========================================
#
# Test: Average loss: 95.8016
#
# Train Epoch: 68 	Loss: 45.453262
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> and deficit swelled to the N million from september
# ========================================
#
# Test: Average loss: 96.0404
#
# Train Epoch: 69 	Loss: 45.816341
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> <unk> deficit was to $ N million from august compared the about the dollar 's largest 's also been
# ========================================
#
# Test: Average loss: 96.0379
#
# Train Epoch: 70 	Loss: 45.201630
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> and deficit was to $ N billion in august prompting the for the company 's largest sector to been
# ========================================
#
# Test: Average loss: 96.0708
#
# Train Epoch: 71 	Loss: 44.960957
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company is deficit swelled fueled the N million in august prompting trading that the dollar 's economic court is been
# ========================================
#
# Test: Average loss: 96.1965
#
# Train Epoch: 72 	Loss: 45.051399
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company is deficit swelled to $ N million in august prompting spending from the dollar 's largest sector was $
# ========================================
#
# Test: Average loss: 96.3020
#
# Train Epoch: 73 	Loss: 45.129230
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> <unk> deficit swelled to $ N billion in september
# ========================================
#
# Test: Average loss: 96.4742
#
# Train Epoch: 74 	Loss: 45.137096
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company unit deficit swelled N N N million from N prompting rising about level dollar 's largest sector was been
# ========================================
#
# Test: Average loss: 96.4654
#
# Train Epoch: 75 	Loss: 45.498779
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> unit deficit was to N N million from august and the about the earthquake 's largest manufacturing is been
# ========================================
#
# Test: Average loss: 96.6132
#
# Train Epoch: 76 	Loss: 44.273876
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> has deficit swelled to $ N million in september prompting the the the company 's earthquake sector is subdued
# ========================================
#
# Test: Average loss: 96.7459
#
# Train Epoch: 77 	Loss: 43.676037
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> and deficit swelled to $ N million in august from the the the <unk> 's manufacturing sector is subdued
# ========================================
#
# Test: Average loss: 96.6902
#
# Train Epoch: 78 	Loss: 43.203869
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> chamber deficit swelled to N N billion from september
# ========================================
#
# Test: Average loss: 96.8198
#
# Train Epoch: 79 	Loss: 43.228352
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> is deficit swelled fueled the N billion in august prompting the that the economy 's export sector is been
# ========================================
#
# Test: Average loss: 96.9465
#
# Train Epoch: 80 	Loss: 43.300667
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company is deficit swelled to the N million from august
# ========================================
#
# Test: Average loss: 97.0196
#
# Train Epoch: 81 	Loss: 43.705502
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company and deficit said to $ N billion in august prompting the the the earthquake 's fifth level are been
# ========================================
#
# Test: Average loss: 97.2634
#
# Train Epoch: 82 	Loss: 43.250950
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> <unk> deficit of to the N billion in september after analysts about the economy 's export contribution is n't
# ========================================
#
# Test: Average loss: 97.2989
#
# Train Epoch: 83 	Loss: 43.246170
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> and deficit swelled to the N billion from august from the about the company 's fifth sector stemmed been
# ========================================
#
# Test: Average loss: 97.3996
#
# Train Epoch: 84 	Loss: 43.036812
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company has deficit swelled to the N billion in august from analysts the the company 's economic earthquake is stalled
# ========================================
#
# Test: Average loss: 97.5162
#
# Train Epoch: 85 	Loss: 43.350758
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> has deficit swelled to N N million in august from $ about the dollar 's economic sector is n't the
# ========================================
#
# Test: Average loss: 97.5067
#
# Train Epoch: 86 	Loss: 43.322937
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company is deficit swelled to N N billion in august prompting the about the economy 's economic expansion violated been
# ========================================
#
# Test: Average loss: 97.6218
#
# Train Epoch: 87 	Loss: 42.625027
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> is deficit swelled to $ N million in september from level that the company 's <unk> sector practices stalled
# ========================================
#
# Test: Average loss: 97.6850
#
# Train Epoch: 88 	Loss: 42.369701
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> unit deficit swelled to the N million in august prompting the that the company 's government process is $
# ========================================
#
# Test: Average loss: 97.9310
#
# Train Epoch: 89 	Loss: 42.049969
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> has deficit swelled to N N million from N from mostly about the dollar 's fifth recovery is <unk>
# ========================================
#
# Test: Average loss: 97.9702
#
# Train Epoch: 90 	Loss: 41.872696
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> <unk> deficit swelled to N N billion in august prompting construction about the company 's export court is been
# ========================================
#
# Test: Average loss: 98.1053
#
# Train Epoch: 91 	Loss: 42.729015
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company is deficit swelled to $ N billion from august prompting analysts the the <unk> 's <unk> sector rose been by
# ========================================
#
# Test: Average loss: 98.1509
#
# Train Epoch: 92 	Loss: 41.144131
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> is deficit was to the N billion in august prompting the about the earthquake 's <unk> goods is stalled
# ========================================
#
# Test: Average loss: 98.3207
#
# Train Epoch: 93 	Loss: 42.001938
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> and deficit swelled to $ N million in september and expectations the the company 's manufacturing rate rate been
# ========================================
#
# Test: Average loss: 98.3037
#
# Train Epoch: 94 	Loss: 40.980373
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company is deficit swelled to $ N billion in august prompting the about the economy 's economic sector are n't
# ========================================
#
# Test: Average loss: 98.4379
#
# Train Epoch: 95 	Loss: 41.152931
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company is deficit warned to $ N billion from august from level that level company 's accumulated <unk> is been
# ========================================
#
# Test: Average loss: 98.4874
#
# Train Epoch: 96 	Loss: 40.800098
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the company trust deficit swelled to N N billion from september prompting the about the dollar 's accumulated sector was n't
# ========================================
#
# Test: Average loss: 98.7072
#
# Train Epoch: 97 	Loss: 40.631226
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> has deficit swelled to $ N million in august prompting $ the the company 's largest examples practices been
# ========================================
#
# Test: Average loss: 98.7954
#
# Train Epoch: 98 	Loss: 41.463730
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> is deficit swelled to $ N billion in the prompting the that the dollar 's export governments is been
# ========================================
#
# Test: Average loss: 98.8233
#
# Train Epoch: 99 	Loss: 40.290657
# train real sentence: <s> the u.s. trade deficit swelled to $ N billion in august prompting worries that the nation 's export drive had stalled
# train gen. sentence: <s> the <unk> underestimated deficit swelled to N N million in september prompting the that the company 's largest <unk> was been
# ========================================
#
# Test: Average loss: 98.9696
#
# Training is done!!
